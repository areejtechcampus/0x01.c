# %% [markdown]
# <a href="https://colab.research.google.com/github/areejtechcampus/0x01.c/blob/master/05Assessment_semantic_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [**Open In Colab**](https://colab.research.google.com/github/HassanAlgoz/agentic-ai-systems/blob/main/Lessons/L01/05_semantic_search.ipynb)
#
# # Semantic Search: Indexing and Retrieval
#
# [Source: Build a semantic search engine with LangChain | LangChain](https://docs.langchain.com/oss/python/langchain/knowledge-base).

# %% [markdown]
# Here we will build a search engine over a PDF document. This will allow us to retrieve passages in the PDF that are similar to an input query.
#
# This guide focuses on LangChain's abstractions related to indexing and retrieval of text data:
#
# * [Documents and document loaders](https://docs.langchain.com/oss/python/integrations/document_loaders);
# * [Text splitters](https://docs.langchain.com/oss/python/integrations/splitters);
# * [Embeddings](https://docs.langchain.com/oss/python/integrations/text_embedding);
# * [Vector stores](https://docs.langchain.com/oss/python/integrations/vectorstores) and [retrievers](https://docs.langchain.com/oss/python/integrations/retrievers).

# %% [markdown]
# 1. **Indexing**
#    1. **Input processing** – Transform raw data into structured documents
#    2. **Embedding & storage** – Convert text into searchable vector representations
# 2. **Retrieval** – Find relevant information based on user queries
#
# This *Relevant context* would later be augmented (added) into an LLM's context window, allowing the LLM to answer questions based on data. The term for this kind of interaction is called: **Retrieval Augmented Generation (RAG)**.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Installation
#
# This tutorial requires the `langchain-community` and `pypdf` packages. Using [uv](https://docs.astral.sh/uv/):

# %% [markdown]
# ```bash
# %pip install langchain-community pypdf
# ```

# %% [markdown]
# For more details, see our [Installation guide](https://docs.langchain.com/oss/python/langchain/install).

# %% [markdown]
# ## 1. Documents and document loaders
#
# LangChain implements a [Document](https://reference.langchain.com/python/langchain_core/documents/#langchain_core.documents.base.Document) abstraction, which is intended to represent a unit of text and associated metadata. It has three attributes:
#
# * `page_content`: a string representing the content;
# * `metadata`: a dict containing arbitrary metadata;
# * `id`: (optional) a string identifier for the document.
#
# The `metadata` attribute can capture information about the source of the document, its relationship to other documents, and other information. Note that an individual [`Document`](https://reference.langchain.com/python/langchain_core/documents/#langchain_core.documents.base.Document) object often represents a chunk of a larger document.
#
# We can generate sample documents when desired:

# %%
# %pip install langchain-community pypdf
# Out:
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.12/dist-packages (0.4.1)
# Requirement already satisfied: pypdf in /usr/local/lib/python3.12/dist-packages (6.8.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (1.2.17)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (1.0.2)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.48)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.7.13)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (26.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.14.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.2.25)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)

# %%
# !pip install langchain-community langchain-huggingface faiss-cpu pypdf sentence-transformers nest_asyncio
# Out:
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.12/dist-packages (0.4.1)
# Requirement already satisfied: langchain-huggingface in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.13.2)
# Requirement already satisfied: pypdf in /usr/local/lib/python3.12/dist-packages (6.8.0)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.2.3)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (1.6.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (1.2.17)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (1.0.2)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.48)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.7.13)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in /usr/local/lib/python3.12/dist-packages (from langchain-huggingface) (1.5.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /usr/local/lib/python3.12/dist-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (26.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (5.0.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.10.0+cpu)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.25.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.24.1)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.14.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.2.25)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.1.2)

# %%
from langchain_core.documents import Document

documents = [
    Document(
        page_content="AWS detalis course",
        metadata={"source": "/AWS Course - All Slides.pdf"},
    ),

]

# %% [markdown]
# However, the LangChain ecosystem implements [document loaders](https://docs.langchain.com/oss/python/langchain/retrieval#document-loaders) that [integrate with hundreds of common sources](https://docs.langchain.com/oss/python/integrations/document_loaders/). This makes it easy to incorporate data from these sources into your AI application.

# %%
from langchain_community.document_loaders import PyPDFLoader

file_path = "/AWS Course - All Slides.pdf"
loader = PyPDFLoader(file_path)

docs = loader.load()

print(len(docs))
# Out:
# WARNING:pypdf._reader:Ignoring wrong pointing object 10 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 20 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 22 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 24 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 47 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 49 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 53 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 55 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 57 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 145 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 147 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 149 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 166 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 196 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 226 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 795 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 797 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 799 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 824 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 826 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 828 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 834 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 836 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 858 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 860 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 862 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1240 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1242 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1244 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1250 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1252 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1274 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1276 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1278 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1300 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1302 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1304 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1806 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1808 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1810 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1816 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1818 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1840 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1842 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1844 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1980 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1982 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1984 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1990 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 1992 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2014 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2016 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2018 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2024 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2046 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2048 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2050 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2143 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2145 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2147 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2153 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2155 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2177 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2179 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2181 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2187 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2209 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2211 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2213 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2235 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2237 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2239 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2261 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2263 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2265 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2471 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2473 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2475 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2481 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2483 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2505 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2507 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2509 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2515 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2537 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2539 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2541 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2563 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2565 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2567 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2589 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2591 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 2593 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11486 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11488 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11490 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11498 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11500 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11744 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11746 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11748 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11750 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11754 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11756 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11758 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11760 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11780 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11782 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11784 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11786 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11790 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11792 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11798 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11824 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11826 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11828 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11830 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11834 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11836 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11840 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11842 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11880 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11882 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11884 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11886 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11892 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11894 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11896 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11898 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11936 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11938 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11940 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11966 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11968 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11970 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11972 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12006 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12008 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12010 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12012 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12016 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12018 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12020 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12022 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12024 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12048 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12050 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12052 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12054 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12058 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12060 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12062 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12086 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12088 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12092 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12094 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12096 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12117 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12119 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12121 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12127 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12149 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12151 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12153 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12157 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12216 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12218 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12220 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12224 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12226 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12260 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12262 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12266 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12268 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12270 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12272 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12274 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12276 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12314 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12316 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12320 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12322 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12324 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12326 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12328 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12352 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12354 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12358 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12360 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12362 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12364 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12366 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12368 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12392 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12394 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12398 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12400 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12402 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12404 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12406 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12408 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12432 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12434 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12436 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12438 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12440 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12442 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12475 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12477 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12481 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12483 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12485 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12487 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12489 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12491 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12495 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12497 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12519 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12521 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12525 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12527 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12529 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12531 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12535 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12537 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12559 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12561 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12563 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12565 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12567 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12569 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12601 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12603 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12607 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12609 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12611 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12613 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12615 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12617 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12625 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12675 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12677 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12679 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12681 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12685 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12687 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12689 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12737 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12739 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12741 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12743 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12745 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12747 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12749 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12782 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12784 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12786 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12792 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12814 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12816 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12818 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12822 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12824 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12908 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12910 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12912 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12914 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12918 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12920 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12922 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12924 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12948 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12950 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12954 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12956 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12958 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12960 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12962 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12986 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12988 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12992 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12994 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12996 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 12998 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13000 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13025 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13027 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13031 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13033 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13035 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13037 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13039 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13063 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13065 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13067 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13069 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13075 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13077 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13103 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13149 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13151 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13155 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13157 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13159 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13161 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13165 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13187 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13189 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13191 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13193 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13195 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13197 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13199 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13231 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13233 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13237 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13239 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13241 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13243 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13245 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13269 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13271 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13275 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13277 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13279 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13281 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13283 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13285 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13324 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13326 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13328 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13332 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13334 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13336 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13338 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13360 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13362 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13364 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13386 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13388 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13390 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13392 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13396 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13398 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13400 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13408 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13410 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13436 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13438 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13442 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13444 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13464 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13466 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13468 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13474 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13496 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13498 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13500 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13506 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13512 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13548 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13550 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13552 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13570 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13572 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13574 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13578 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13580 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13615 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13617 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13619 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13621 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13625 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13627 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13629 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13661 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13663 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13665 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13667 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13671 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13673 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13675 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13712 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13714 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13716 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13738 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13740 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13742 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13744 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13748 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13750 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13780 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13782 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13784 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13806 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13808 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13812 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13814 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13818 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13820 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13844 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13846 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13848 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13871 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13873 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13877 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13879 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13883 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13885 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13907 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13909 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13911 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13915 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13917 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13939 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13941 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13943 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13965 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13967 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13971 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13973 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13975 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13979 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13981 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 13983 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14008 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14010 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14014 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14016 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14018 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14022 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14024 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14048 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14050 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14052 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14074 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14076 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14080 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14082 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14084 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14086 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14088 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14112 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14114 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14118 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14120 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14124 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14126 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14149 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14151 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14155 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14157 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14161 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14163 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14199 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14201 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14203 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14205 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14209 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14211 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14237 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14239 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14241 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14243 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14247 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14249 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14253 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14279 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14281 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14283 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14305 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14307 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14309 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14315 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14317 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14348 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14350 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 14352 0 (offset 0)
# 879

# %% [markdown]
# `PyPDFLoader` loads one [`Document`](https://reference.langchain.com/python/langchain_core/documents/#langchain_core.documents.base.Document) object per PDF page. For each, we can easily access:
#
# * The string content of the page;
# * Metadata containing the file name and page number.

# %%
print(f"{docs[0].page_content[:200]}\n")
print(docs[0].metadata)
# Out:
# AWS CERTIFIED SOLUTIONS ARCHITECT ASSOCIATE Student e-Notebook                                                      Version 1.0
#
# {'producer': 'macOS Version 10.15.7 (Build 19H114) Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20210205072054Z00'00'", 'title': 'Course e-Notebook wout notes Color', 'author': 'Eissa Abousherif www.dolfined.com', 'moddate': "D:20210205072054Z00'00'", 'source': '/AWS Course - All Slides.pdf', 'total_pages': 879, 'page': 0, 'page_label': '1'}

# %% [markdown]
# ### Splitting
#
# For both information retrieval and downstream question-answering purposes, a page may be too coarse a representation. Our goal in the end will be to retrieve [`Document`](https://reference.langchain.com/python/langchain_core/documents/#langchain_core.documents.base.Document) objects that answer an input query, and further splitting our PDF will help ensure that the meanings of relevant portions of the document are not "washed out" by surrounding text.
#
# We can use [text splitters](https://docs.langchain.com/oss/python/langchain/retrieval#text_splitters) for this purpose. Here we will use a simple text splitter that partitions based on characters. We will split our documents into chunks of 1000 characters with 200 characters of overlap between chunks. The overlap helps mitigate the possibility of separating a statement from important context related to it. We use the `RecursiveCharacterTextSplitter`, which will recursively split the document using common separators like new lines until each chunk is the appropriate size. This is the recommended text splitter for generic text use cases.
#
# We set `add_start_index=True` so that the character index where each split Document starts within the initial Document is preserved as metadata attribute `start_index`.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, chunk_overlap=200, add_start_index=True
)
all_splits = text_splitter.split_documents(docs)

print(len(all_splits))
# Out:
# 930

# %% [markdown]
# ## 2. Embeddings
#
# Vector search is a common way to store and search over unstructured data (such as unstructured text). The idea is to store numeric vectors that are associated with the text. Given a query, we can [embed](https://docs.langchain.com/oss/python/langchain/retrieval#embedding_models) it as a vector of the same dimension and use vector similarity metrics (such as cosine similarity) to identify related text.
#
# LangChain supports embeddings from [dozens of providers](https://docs.langchain.com/oss/python/integrations/text_embedding/). These models specify how text should be converted into a numeric vector. We use HuggingFace with the `all-mpnet-base-v2` sentence transformer:
#
# ```bash
# %pip install langchain-huggingface sentence-transformers
# ```

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
vector_1 = embeddings.embed_query(all_splits[0].page_content)
vector_2 = embeddings.embed_query(all_splits[1].page_content)

assert len(vector_1) == len(vector_2)
print(f"Generated vectors of length {len(vector_1)}\n")
print(vector_1[:10])
# Out:
# Generated vectors of length 768
#
# [-0.000768802419770509, -0.04732697457075119, -0.03251934051513672, -0.011239398270845413, 0.034204721450805664, -0.01058821752667427, 0.04397312179207802, -0.0033209279645234346, -0.012506824918091297, 0.00011961268319282681]

# %% [markdown]
# Armed with a model for generating text embeddings, we can next store them in a special data structure that supports efficient similarity search.

# %% [markdown]
# ## 3. Vector stores
#
# LangChain [VectorStore](https://reference.langchain.com/python/langchain_core/vectorstores/?h=#langchain_core.vectorstores.base.VectorStore) objects contain methods for adding text and [`Document`](https://reference.langchain.com/python/langchain_core/documents/#langchain_core.documents.base.Document) objects to the store, and querying them using various similarity metrics. They are often initialized with [embedding](https://docs.langchain.com/oss/python/langchain/retrieval#embedding_models) models, which determine how text data is translated to numeric vectors.
#
# LangChain includes a suite of [integrations](https://docs.langchain.com/oss/python/integrations/vectorstores) with different vector store technologies. For this tutorial we use the **in-memory** vector store, which is lightweight and requires no extra infrastructure:

# %%
from langchain_core.vectorstores import InMemoryVectorStore

vector_store = InMemoryVectorStore(embeddings)

# %% [markdown]
# Having instantiated our vector store, we can now index the documents.

# %%
ids = vector_store.add_documents(documents=all_splits)

# %% [markdown]
# Note that most vector store implementations will allow you to connect to an existing vector store--  e.g., by providing a client, index name, or other information. See the documentation for a specific [integration](https://docs.langchain.com/oss/python/integrations/vectorstores) for more detail.
#
# Once we've instantiated a [`VectorStore`](https://reference.langchain.com/python/langchain_core/vectorstores/?h=#langchain_core.vectorstores.base.VectorStore) that contains documents, we can query it. [VectorStore](https://reference.langchain.com/python/langchain_core/vectorstores/?h=#langchain_core.vectorstores.base.VectorStore) includes methods for querying:
#
# * Synchronously and asynchronously;
# * By string query and by vector;
# * With and without returning similarity scores;
# * By similarity and [maximum marginal relevance](https://reference.langchain.com/python/langchain_core/vectorstores/?h=#langchain_core.vectorstores.base.VectorStore.max_marginal_relevance_search) (to balance similarity with query to diversity in retrieved results).
#
# The methods will generally include a list of [Document](https://reference.langchain.com/python/langchain_core/documents/#langchain_core.documents.base.Document) objects in their outputs.
#
# **Usage**
#
# Embeddings typically represent text as a "dense" vector such that texts with similar meanings are geometrically close. This lets us retrieve relevant information just by passing in a question, without knowledge of any specific key-terms used in the document.
#
# Return documents based on similarity to a string query:

# %%
results = vector_store.similarity_search(
    "What is the main topic of this document?"
)

print(results[0])
# Out:
# page_content='AWS Certified Solutions Architect Associate SAA-C02 Student e-Notebook
#                                                                              www.dolfined.com
# 440 © DolfinED All rights reserved
# Amazon DocumentDB and Amazon Neptune' metadata={'producer': 'macOS Version 10.15.7 (Build 19H114) Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20210205072054Z00'00'", 'title': 'Course e-Notebook wout notes Color', 'author': 'Eissa Abousherif www.dolfined.com', 'moddate': "D:20210205072054Z00'00'", 'source': '/AWS Course - All Slides.pdf', 'total_pages': 879, 'page': 440, 'page_label': '441', 'start_index': 0}

# %% [markdown]
# Async query:

# %%
results = await vector_store.asimilarity_search("What is self-attention?")

print(results[0])
# Out:
# page_content='AWS Certified Solutions Architect Associate SAA-C02 Student e-Notebook
#                                                                              www.dolfined.com
# 803 © DolfinED All rights reserved
#
# Amazon CognitoSecurity, Identity, and Access Management
# © DolfinEDAll rights reserved
# AmazonCognitoprovidesauthentication,authorization,andusermanagementforwebandmobileapplications.ThemaintwocomponentsofCognitoare:•CognitoUserPools:Providesuserdirectoriesthatprovidesign-upandsign-inoptionsforusers.•CognitoIdentitypools:CanbeusedtograntAWScredentials(STS)toaccessAWSservices.Theycanbeusedseparatelyortogether.' metadata={'producer': 'macOS Version 10.15.7 (Build 19H114) Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20210205072054Z00'00'", 'title': 'Course e-Notebook wout notes Color', 'author': 'Eissa Abousherif www.dolfined.com', 'moddate': "D:20210205072054Z00'00'", 'source': '/AWS Course - All Slides.pdf', 'total_pages': 879, 'page': 803, 'page_label': '804', 'start_index': 0}

# %% [markdown]
# Return scores:

# %%
# Note that providers implement different scores; the score here
# is a distance metric that varies inversely with similarity.

results = vector_store.similarity_search_with_score("How does the Transformer encoder work?")
doc, score = results[0]
print(f"Score: {score}\n")
print(doc)
# Out:
# Score: 0.39219678611199804
#
# page_content='AWS Certified Solutions Architect Associate SAA-C02 Student e-Notebook
#                                                                              www.dolfined.com
# 860 © DolfinED All rights reserved
#
# Amazon Elastic TranscoderAmazon Media, Mobile, End User, and IoT Services
# © DolfinEDAll rights reserved
# ElasticTranscodermanagesthecomplexityofrunningmediatranscodingjobsatascaleinAWS.•Itisusedtoconvertvideoandaudio(media)filesstoredinS3intosupportedoutputformatsforplaybackonuserdevices.•Itsupportswiderangeofoutputformats,resolutions,bitrates,andframerates.•Isapayforwhatyouuseservice(hasafreetier).' metadata={'producer': 'macOS Version 10.15.7 (Build 19H114) Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20210205072054Z00'00'", 'title': 'Course e-Notebook wout notes Color', 'author': 'Eissa Abousherif www.dolfined.com', 'moddate': "D:20210205072054Z00'00'", 'source': '/AWS Course - All Slides.pdf', 'total_pages': 879, 'page': 860, 'page_label': '861', 'start_index': 0}

# %% [markdown]
# Return documents based on similarity to an embedded query:

# %%
embedding = embeddings.embed_query("What are the advantages of the Transformer over RNNs?")

results = vector_store.similarity_search_by_vector(embedding)
print(results[0])
# Out:
# page_content='843 © DolfinED All rights reserved
#
# Amazon Kinesis Data Stream vs. SQS -when to use what?AWS Analytics Services
# © DolfinEDAll rights reserved
# Kinesis Data StreamsSQSIntended useReal-time ingestion and processing of streaming big data.Reliable, highly scalable hosted queue for storing messages as they travel between computers.OrderingOrdering of records, and ability to read/replay records in the same order by several Kinesis applications.SQS FIFO queues can guarantee message ordering.Use when your requirements are any of the following:•Routing related records to the same record processor (consumer). •When we need ordering of records (Important in case we need to keep the order of logs messages the same at the consumer as they arrived from the producers). •When we need multiple applications to consume the records concurrently. •The ability to consume the same records few hours or couple of days later.' metadata={'producer': 'macOS Version 10.15.7 (Build 19H114) Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20210205072054Z00'00'", 'title': 'Course e-Notebook wout notes Color', 'author': 'Eissa Abousherif www.dolfined.com', 'moddate': "D:20210205072054Z00'00'", 'source': '/AWS Course - All Slides.pdf', 'total_pages': 879, 'page': 843, 'page_label': '844', 'start_index': 218}

# %% [markdown]
# Learn more:
#
# * [API Reference](https://reference.langchain.com/python/langchain_core/vectorstores/?h=#langchain_core.vectorstores.base.VectorStore)
# * [Integration-specific docs](https://docs.langchain.com/oss/python/integrations/vectorstores)

# %% [markdown]
# ## 4. Retrievers

# %% [markdown]
# Vectorstores implement an `as_retriever` method that will generate a Retriever, specifically a [`VectorStoreRetriever`](https://python.langchain.com/api_reference/core/vectorstores/langchain_core.vectorstores.base.VectorStoreRetriever.html). These retrievers include specific `search_type` and `search_kwargs` attributes that identify what methods of the underlying vector store to call, and how to parameterize them. For instance, we can replicate the above with the following:

# %%
retriever = vector_store.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 1},
)

retriever.batch(
    [
        "What is the main topic of this document?",
        "What is self-attention?",
    ],
)
# Out:
# [[Document(id='cccd0511-3baa-451a-9b70-2b13ae2b3f4e', metadata={'producer': 'macOS Version 10.15.7 (Build 19H114) Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20210205072054Z00'00'", 'title': 'Course e-Notebook wout notes Color', 'author': 'Eissa Abousherif www.dolfined.com', 'moddate': "D:20210205072054Z00'00'", 'source': '/AWS Course - All Slides.pdf', 'total_pages': 879, 'page': 440, 'page_label': '441', 'start_index': 0}, page_content='AWS Certified Solutions Architect Associate SAA-C02 Student e-Notebook               \n                                                                             www.dolfined.com                                      \n440 © DolfinED All rights reserved  \nAmazon DocumentDB and Amazon Neptune')],
#  [Document(id='34b6a30e-9f2b-4049-806d-a40838d163d1', metadata={'producer': 'macOS Version 10.15.7 (Build 19H114) Quartz PDFContext', 'creator': 'Word', 'creationdate': "D:20210205072054Z00'00'", 'title': 'Course e-Notebook wout notes Color', 'author': 'Eissa Abousherif www.dolfined.com', 'moddate': "D:20210205072054Z00'00'", 'source': '/AWS Course - All Slides.pdf', 'total_pages': 879, 'page': 803, 'page_label': '804', 'start_index': 0}, page_content='AWS Certified Solutions Architect Associate SAA-C02 Student e-Notebook               \n                                                                             www.dolfined.com                                      \n803 © DolfinED All rights reserved  \n   \nAmazon CognitoSecurity, Identity, and Access Management \n© DolfinEDAll rights reserved\nAmazonCognitoprovidesauthentication,authorization,andusermanagementforwebandmobileapplications.ThemaintwocomponentsofCognitoare:•CognitoUserPools:Providesuserdirectoriesthatprovidesign-upandsign-inoptionsforusers.•CognitoIdentitypools:CanbeusedtograntAWScredentials(STS)toaccessAWSservices.Theycanbeusedseparatelyortogether.')]]

# %% [markdown]
# `VectorStoreRetriever` supports search types of `"similarity"` (default), `"mmr"` (maximum marginal relevance, described above), and `"similarity_score_threshold"`. We can use the latter to threshold documents output by the retriever by similarity score.

# %% [markdown]
# ## Key Takeaways
#
# - **Indexing vs. retrieval** – Indexing turns raw data into structured documents and embeds them for search; retrieval finds relevant passages for a query. Together they form the basis of **RAG (Retrieval Augmented Generation)**.
# - **Documents** – LangChain’s `Document` has `page_content`, `metadata`, and optional `id`. Use **document loaders** (e.g. `PyPDFLoader`) to load from PDFs and other sources.
# - **Chunking** – Split documents into smaller chunks (e.g. with `RecursiveCharacterTextSplitter`) so retrieval returns focused passages; use **overlap** to avoid cutting off context.
# - **Embeddings** – Text is turned into dense vectors (e.g. via HuggingFace `all-mpnet-base-v2`); similar meaning → similar vectors, enabling **semantic** (meaning-based) search instead of keyword match.
# - **Vector stores** – Store and query embeddings (e.g. `InMemoryVectorStore`); support sync/async, by query or by vector, with or without scores, and **MMR** for diversity.
# - **Retrievers** – Use `vector_store.as_retriever()` with `search_type` (`"similarity"`, `"mmr"`, `"similarity_score_threshold"`) and `search_kwargs` (e.g. `k`) for easy integration into chains and RAG pipelines.
